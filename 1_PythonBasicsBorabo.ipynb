# %% [markdown]
# <a href="https://colab.research.google.com/github/lulli30/DataSciencePractice/blob/main/1_PythonBasicsBorabo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Python Basics**

# %% [markdown]
# ### Printing, Variables, Arithmetic

# %%
# Print
print('I already love Python')
# Out:
# I already love Python

# %%
# Variables and assignment
a = 10
print(a)
b = 5
print(b)
# Out:
# 10
# 5

# %%
# Arithmetic
# Note variable values persist from previous cell
print(a + b)
print(b - a)
print(a * b)
print(b / a)
# Out:
# 15
# -5
# 50
# 0.5

# %%
# Update
a = a + b
print(a)
# Out:
# 15

# %%
# Increment
a += b
print(a)
# Out:
# 20

# %% [markdown]
# ### Types

# %%
# Dynamically-inferred types
a = 10
print(type(a))
a = '10'
print(type(a))
a = 10.0
print(type(a))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
# Type-checking
a = 10
b = '5'
# The error occurs here because you are trying to add an integer (a) and a string (b).
# Python does not implicitly convert a string to an integer for arithmetic operations.
# To fix this, convert the string 'b' to an integer using int(b).
print(a + int(b))
# Out:
# 15

# %%
# Manual type-conversion (string to int)
a = 10
b = '5'
print(a + int(b))
# Out:
# 15

# %%
# Automatic type-conversion (int to float)
a = 10
print(type(a))
a += 5.0
print(a, type(a))
# Out:
# <class 'int'>
# 15.0 <class 'float'>

# %%
# String "arithmetic" (actually concatenation)
a = 'Professor '
b = 'Widom'
print(a + b)
# Out:
# Professor Widom

# %% [markdown]
# ### Conditional (If) Statements

# %%
# If statements
# Unlike other languages, indentation is significant
a = 8
if a > 10:
    print(a, 'is greater than 10')
    if a >= 15:
        print(a, 'is also at least 15')
elif a > 5:
    print(a, 'is greater than 5 but not greater than 10')
else:
    print('no condition matched')
    print('so a is 5 or less')
# Out:
# 8 is greater than 5 but not greater than 10

# %% [markdown]
# ### <font color = 'green'>**Your Turn**</font>

# %%
# Write a program that starts with a number assigned to variable a.
# If the square of that number is 100 or greater,
# print the squared value and 'is big'.
# Otherwise if the square is 50 or greater,
# print the squared value 'is medium'.
# Otherwise just print 'too small to bother with'.
# Note: To obtain a value squared, use a*a or a**2
# Make sure to try different values for a

a = 8
square = a * a
if square >= 100:
    print(square, "is big")
elif square >= 50:
    print(square, "is medium")
else:
    print("too small to bother with")
# Out:
# 64 is medium

# %% [markdown]
# ### Lists and For-Loops

# %%
# List
a = [2, 4, 7, 9]
print(a)
print(type(a))
print(len(a))
# Out:
# [2, 4, 7, 9]
# <class 'list'>
# 4

# %%
# Iterate through a list
for item in a:
    print(item, 2 * item)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1147815006.py in <cell line: 0>()
#       1 # Iterate through a list
# ----> 2 for item in a:
#       3     print(item, 2 * item)
#
# TypeError: 'int' object is not iterable

# %%
# Access element by index (starts at zero)
print(a)
print(a[-1])
print(a[-3])

# %%
# Prefix, suffix, and section of list
print(a)
print(a[:2])
print(a[1:])
print(a[1:3])

# %%
# Append to list
a.append(12)
a.append(14)
print(a)

# %%
# Combine two lists
a = a + [15, 20, 30]
print(a)

# %%
# List elements can be of different types
a = [1, 'two', 3.0, [4,5,6]]
print(a)
print(type(a))
print(type(a[0]), type(a[1]), type(a[2]), type (a[3]))

# %% [markdown]
# ### Dictionaries (key-value mappings)

# %%
# Dictionary
a = {'name': 'Mary', 'age': 20, 'gender': 'F'}
print(a)
print(type(a))

# %%
# Look up value of element by key - most important feature!
print(a['age'])
# also try a['gender'], a['salary']

# %%
# Modify value
print(a)
a['age'] = 20
print(a)

# %%
# Add new key-value pair
a['salary'] = 100
print(a)

# %%
# Iterating through a list of dictionaries
dlist = [{'name':'Mary', 'age':20}, {'name':'John', 'age':30},
         {'name':'Bill', 'age':10}, {'name':'Susan', 'age':40}]
for x in dlist:
    if x['age'] >= 30:
        print(x['name'], 'is old')
    if x['age'] < 20:
        print(x['name'], 'is young')

# %% [markdown]
# ### <font color = 'green'>**Your Turn**</font>

# %%
# Here is a dataset of four items, represented as a list of
# dictionaries specifying each item's color and size
items = [{'color':'red', 'size':10}, {'color':'blue', 'size':3},
         {'color':'green', 'size':15}, {'color':'yellow', 'size':6}]
# Write code that prints the color of all items whose size
# is greater than threshold 'low' and less than threshold 'high'
# Note: In Python, use 'and' to combine conditions
low = 5
high = 12

for item in items:
    if item['size'] > low and item['size'] < high:
        print(item['color'])
# Out:
# red
# yellow

# %% [markdown]
# ### Additional Features - Mostly Just FYI

# %% [markdown]
# #### User input

# %%
a = input('Enter value 1: ')
b = input('Enter value 2: ')
print(a + b)
# Fix to do integer addition

# %% [markdown]
# #### While loops

# %%
# Echo user input, 'quit' to end
i = input('Enter any string, or "quit" to stop: ')
while i != 'quit':
    print(i)
    i = input('Enter any string, or "quit" to stop: ')
print('Done')
# Change to while True and break

# %% [markdown]
# #### Infinite while loop

# %%
# Try not 'quit' then try 'quit', Runtime > interrupt
i = input('Enter any string, or "quit" to stop: ')
while True:
    if i != 'quit': print(i)
print('Done')

# %% [markdown]
# #### Functions

# %%
# Create a function with no arguments or return value
def simple():
    print('This function has no arguments or return value')

simple()

# %%
# Call the function five times
for i in [1,2,3,4,5]:
    simple()

# %%
# Create a function with arguments and a return value
def addthem(a, b):

    return a + b

# %%
# Call the function five times
for i in [1,2,3,4,5]:
    print(i, i+1, addthem(i,i+1))
